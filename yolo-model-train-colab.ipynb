# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# %cd ..
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17360, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 17360 (delta 31), reused 12 (delta 9), pack-reused 17310 (from 4)
# Receiving objects: 100% (17360/17360), 16.24 MiB | 17.66 MiB/s, done.
# Resolving deltas: 100% (11893/11893), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c594c7b2-f15b-4125-bda6-8eea9b5a5c46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c594c7b2-f15b-4125-bda6-8eea9b5a5c46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                               title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# atharvasoundankar/chocolate-sales                                 Chocolate Sales Data 📊🍫                         14KB  2025-03-19 03:51:40          14108        249  1.0
# khushikyad001/indian-traffic-violation                            Indian Traffic Violation                       164KB  2025-03-27 04:18:21           1049         23  1.0
# adilshamim8/student-depression-dataset                            Student Depression Dataset                     456KB  2025-03-13 03:12:30           5855         94  1.0
# ...

# %%
# !kaggle datasets download -d douaairaq/rice-disease-dataset-labelled-to-train-yolov5
# !unzip rice-disease-dataset-labelled-to-train-yolov5.zip -d rice_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: rice_dataset/valid/labels/blasst-202-_jpg.rf.1b989a73dce576b0b326486f84320bab.txt
#   inflating: rice_dataset/valid/labels/blasst-203-_jpg.rf.946676d6b7cf62a68551587fc1db15d1.txt
#   inflating: rice_dataset/valid/labels/blasst-204-_jpg.rf.e0f94c70fc6b33228727ffaf85f20e78.txt
#   inflating: rice_dataset/valid/labels/blasst-205-_jpg.rf.264c503555f6c853688861b15710a321.txt
#   inflating: rice_dataset/valid/labels/blasst-205-_jpg.rf.fdbc3df56e1e30941709deeca31ab963.txt
#   inflating: rice_dataset/valid/labels/blasst-206-_jpg.rf.9f25d37224f89a70422c19374633055b.txt
#   inflating: rice_dataset/valid/labels/blasst-207-_jpg.rf.348b115feec7d07233488177d6d4e419.txt
#   inflating: rice_dataset/valid/labels/blasst-208-_jpg.rf.a5f85ed71cfcfaf011614d55f7d3e99e.txt
#   inflating: rice_dataset/valid/labels/blasst-209-_jpg.rf.6abeb3c8e2cf674d238c117f75c0677d.txt
# ...

# %%
# %%writefile /content/rice_dataset/data.yaml
# path: /content/rice_dataset
# train: /content/rice_dataset/train/images
# val: /content/rice_dataset/valid/images
# test: /content/rice_dataset/test/images
#
# nc: 2
# names: ['disease', 'normal']
# Out:
# Overwriting /content/rice_dataset/data.yaml

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 32 --epochs 10 --data /content/rice_dataset/data.yaml --weights yolov5s.pt --device 0
# Out:
# Streaming output truncated to the last 5000 lines.
#         1/9      8.59G    0.05125    0.03715   0.000363        193        640:  61% 843/1383 [10:28<05:54,  1.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/9      8.59G    0.05125    0.03715  0.0003632        158        640:  61% 844/1383 [10:29<08:02,  1.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/9      8.59G    0.05125    0.03715  0.0003632        177        640:  61% 845/1383 [10:29<06:51,  1.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
